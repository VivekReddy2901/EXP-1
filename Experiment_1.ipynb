# %% [markdown]
# Experiment 1 : Introduction to python
#
# Name : Vivek Reddy
#
# PRN : 25070123135

# %%
a,b,c = "APPLE","CHERRY","ORANGE"
print(a,b,c,sep="\n")
# Out:
# APPLE
# CHERRY
# ORANGE

# %%
x,y,z,w = 2,2.23,"VIVEK",True
print(type(x),type(y),type(z),type(w),sep="\n")
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
a,b = 10,5
print("SUM",a+b)
print("SUB",a-b)
print("MULT",a*b)
print("DIV",a/b)
print("EXP",a**b)
# Out:
# SUM 15
# SUB 5
# MULT 50
# DIV 2.0
# EXP 100000

# %%
a=int(input("Enter the value of a:"))
b=int(input("Enter the value of b:"))

print("\nSUM =",a+b,"\nSUB =",a-b,"\nMULT =",a*b,"\nDIV =",a/b,"\nEXP =",a**b)
# Out:
# Enter the value of a:4
# Enter the value of b:6
#
# SUM = 10
# SUB = -2
# MULT = 24
# DIV = 0.6666666666666666
# EXP = 4096

# %%
import math
pi = math.pi

r=float(input("Enter the radius of circle:"))
area = pi*r*r
print("Area of circle =",area)
# Out:
# Enter the radius of circle:6.43
# Area of circle = 129.8888341034046

# %%
import math

a = math.log10(10)
print(a)
# Out:
# 1.0

# %%
a,b = 10,5

if(a>b) :
    print("b is less than a")
    print("b is more than a")
# Out:
# b is less than a
# b is more than a
